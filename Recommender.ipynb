# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv(r"C:\Users\ammar\Downloads\tmdb_5000_movies\tmdb_5000_movies.csv")
credit = pd.read_csv(r"C:\Users\ammar\Downloads\tmdb_5000_credits\tmdb_5000_credits.csv")

# %%
movies.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
credit.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 4 columns]

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
#genres
#id
#keywords
#overview
#title
#cast
#crew

# %%
movies = movies.merge(credit , on="title")

# %%
movies.head()
# Out:
#       budget  ...                                               crew
# 0  237000000  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  300000000  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  245000000  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  250000000  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  260000000  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
movies = movies[["id","title","overview","genres","keywords","cast","crew","release_date","tagline","vote_average"]]

# %%
movies.head()
# Out:
#        id  ... vote_average
# 0   19995  ...          7.2
# 1     285  ...          6.9
# 2  206647  ...          6.3
# 3   49026  ...          7.6
# 4   49529  ...          6.1
#
# [5 rows x 10 columns]

# %%
movies.isnull().sum()
# Out:
# id                0
# title             0
# overview          3
# genres            0
# keywords          0
# cast              0
# crew              0
# release_date      1
# tagline         844
# vote_average      0
# dtype: int64

# %%
movies.dropna(inplace = True)

# %%
movies["genres"][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast

# %%
def convert(obj):
    L = []
    for i in ast.literal_eval(obj):
        L.append(i["name"])
    return L

# %%
movies["gen"] = movies["genres"].apply(convert)

# %%
movies["ge"] = movies['gen']

# %%
movies.head()
# Out:
#        id  ...                                             ge
# 0   19995  ...  [Action, Adventure, Fantasy, Science Fiction]
# 1     285  ...                   [Adventure, Fantasy, Action]
# 2  206647  ...                     [Action, Adventure, Crime]
# 3   49026  ...               [Action, Crime, Drama, Thriller]
# 4   49529  ...           [Action, Adventure, Science Fiction]
#
# [5 rows x 12 columns]

# %%
movies['keywords'][0]
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
movies["keywords"] = movies["keywords"].apply(convert)

# %%
movies.head()
# Out:
#        id  ...                                             ge
# 0   19995  ...  [Action, Adventure, Fantasy, Science Fiction]
# 1     285  ...                   [Adventure, Fantasy, Action]
# 2  206647  ...                     [Action, Adventure, Crime]
# 3   49026  ...               [Action, Crime, Drama, Thriller]
# 4   49529  ...           [Action, Adventure, Science Fiction]
#
# [5 rows x 12 columns]

# %%
movies["cast"][0]
# Out:
# '[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender"
# ...

# %%
def convert2(obj):
    L = []
    counter = 0
    for i in ast.literal_eval(obj):
        if counter != 3:
            L.append(i["name"])
            counter = counter + 1
        else:
            break
    return L

# %%
movies["cast"] = movies["cast"].apply(convert2)

# %%
movies.head()
# Out:
#        id  ...                                             ge
# 0   19995  ...  [Action, Adventure, Fantasy, Science Fiction]
# 1     285  ...                   [Adventure, Fantasy, Action]
# 2  206647  ...                     [Action, Adventure, Crime]
# 3   49026  ...               [Action, Crime, Drama, Thriller]
# 4   49529  ...           [Action, Adventure, Science Fiction]
#
# [5 rows x 12 columns]

# %%
movies["crew"][0]
# Out:
# '[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James Cameron"
# ...

# %%
def convert3(obj):
    L = []
    for i in ast.literal_eval(obj):
        if i["job"] == "Director":
            L.append(i["name"])
            break
    return L

# %%
movies["crew"] = movies["crew"].apply(convert3)

# %%
movies.head()
# Out:
#        id  ...                                             ge
# 0   19995  ...  [Action, Adventure, Fantasy, Science Fiction]
# 1     285  ...                   [Adventure, Fantasy, Action]
# 2  206647  ...                     [Action, Adventure, Crime]
# 3   49026  ...               [Action, Crime, Drama, Thriller]
# 4   49529  ...           [Action, Adventure, Science Fiction]
#
# [5 rows x 12 columns]

# %%
movies["over"] = movies["overview"].apply(lambda x: x.split())

# %%
movies.head()
# Out:
#        id  ...                                               over
# 0   19995  ...  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     285  ...  [Captain, Barbossa,, long, believed, to, be, d...
# 2  206647  ...  [A, cryptic, message, from, Bond’s, past, send...
# 3   49026  ...  [Following, the, death, of, District, Attorney...
# 4   49529  ...  [John, Carter, is, a, war-weary,, former, mili...
#
# [5 rows x 13 columns]

# %%
movies["cast"] = movies["cast"].apply(lambda x: [i.replace(" ","") for i in x])
movies["gen"] = movies["genres"].apply(lambda x: [i.replace(" ","") for i in x])
movies["keywords"] = movies["keywords"].apply(lambda x: [i.replace(" ","") for i in x])
movies["crew"] = movies["crew"].apply(lambda x: [i.replace(" ","") for i in x])

# %%
movies.head()
# Out:
#        id  ...                                               over
# 0   19995  ...  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     285  ...  [Captain, Barbossa,, long, believed, to, be, d...
# 2  206647  ...  [A, cryptic, message, from, Bond’s, past, send...
# 3   49026  ...  [Following, the, death, of, District, Attorney...
# 4   49529  ...  [John, Carter, is, a, war-weary,, former, mili...
#
# [5 rows x 13 columns]

# %%
movies["Tags"] = movies["over"] + movies["keywords"] + movies["gen"] + movies["cast"] + movies["crew"]

# %%
movies.head()
# Out:
#        id  ...                                               Tags
# 0   19995  ...  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     285  ...  [Captain, Barbossa,, long, believed, to, be, d...
# 2  206647  ...  [A, cryptic, message, from, Bond’s, past, send...
# 3   49026  ...  [Following, the, death, of, District, Attorney...
# 4   49529  ...  [John, Carter, is, a, war-weary,, former, mili...
#
# [5 rows x 14 columns]

# %%
movies = movies[["id","title","Tags","release_date","tagline","vote_average","overview","ge"]]

# %%
movies['Tags'] = movies['Tags'].apply(lambda x: " ".join(x))

# %%
movies.head()
# Out:
#        id  ...                                             ge
# 0   19995  ...  [Action, Adventure, Fantasy, Science Fiction]
# 1     285  ...                   [Adventure, Fantasy, Action]
# 2  206647  ...                     [Action, Adventure, Crime]
# 3   49026  ...               [Action, Crime, Drama, Thriller]
# 4   49529  ...           [Action, Adventure, Science Fiction]
#
# [5 rows x 8 columns]

# %%
movies["Tags"] = movies["Tags"].apply(lambda x : x.lower())

# %%
movies.head()
# Out:
#        id  ...                                             ge
# 0   19995  ...  [Action, Adventure, Fantasy, Science Fiction]
# 1     285  ...                   [Adventure, Fantasy, Action]
# 2  206647  ...                     [Action, Adventure, Crime]
# 3   49026  ...               [Action, Crime, Drama, Thriller]
# 4   49529  ...           [Action, Adventure, Science Fiction]
#
# [5 rows x 8 columns]

# %%
import csv
csv.field_size_limit(10**6)  # Increase limit to 1,000,000 characters

poster = pd.read_csv(r"C:\Users\ammar\Downloads\mymoviedb\mymoviedb.csv", engine="python")

# %%
poster.rename(columns={"Title": "title"}, inplace=True)

# %%
mov = movies.merge(poster, on="title")

# %%
movies = mov[['id',"title","Tags","Poster_Url","release_date","tagline","vote_average","overview","ge"]]

# %%
movies.drop_duplicates(subset=["title"], inplace=True)
# Out:
# C:\Users\ammar\AppData\Local\Temp\ipykernel_11652\249049517.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.drop_duplicates(subset=["title"], inplace=True)

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer

# %%
import re

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to c:\Users\ammar\OneDrive\D
# [nltk_data]     esktop\Expirement\experiment\share\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
ps = PorterStemmer()

# %%
def cleaning(tags):
    cleaned = re.sub("[^a-zA-Z0-9]"," ",tags)
    cleaned = cleaned.lower()
    cleaned = cleaned.split()
    cleaned = [ps.stem(word) for word in cleaned]
    cleaned = " ".join(cleaned)
    return cleaned

# %%
movies["Tags"] = movies["Tags"].apply(cleaning)
# Out:
# C:\Users\ammar\AppData\Local\Temp\ipykernel_11652\4085359687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["Tags"] = movies["Tags"].apply(cleaning)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tdf = TfidfVectorizer(stop_words="english")

# %%
vector = tdf.fit_transform(movies["Tags"]).toarray()

# %%
vector[1]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], shape=(20270,))

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity[1]
# Out:
# array([0.        , 1.        , 0.        , ..., 0.        , 0.00477139,
#        0.00428369], shape=(2649,))

# %%
def recommend(movie):
    movie_index = int(movies[movies["title"] == movie].index[0])
    distance = similarity[movie_index]
    movie_list = sorted(list(enumerate(distance)),reverse= True, key= lambda x:x[1])[1:6]

    for i in movie_list:
        print(movies.iloc[i[0]].title)

# %%
recommend("Iron Man")
# Out:
# Snow White and the Seven Dwarfs
# The Huntsman: Winter's War
# The Snow Queen
# Mirror Mirror
# Queen of the Damned

# %%
poster.head()
# Out:
#   Release_Date  ...                                         Poster_Url
# 0   2021-12-15  ...  https://image.tmdb.org/t/p/original/1g0dhYtq4i...
# 1   2022-03-01  ...  https://image.tmdb.org/t/p/original/74xTEgt7R3...
# 2   2022-02-25  ...  https://image.tmdb.org/t/p/original/vDHsLnOWKl...
# 3   2021-11-24  ...  https://image.tmdb.org/t/p/original/4j0PNHkMr5...
# 4   2021-12-22  ...  https://image.tmdb.org/t/p/original/aq4Pwv5Xeu...
#
# [5 rows x 9 columns]

# %%
poster.shape
# Out:
# (9837, 9)

# %%
movies.head()
# Out:
#        id  ...                                             ge
# 0   19995  ...  [Action, Adventure, Fantasy, Science Fiction]
# 1     285  ...                   [Adventure, Fantasy, Action]
# 2  206647  ...                     [Action, Adventure, Crime]
# 3   49026  ...               [Action, Crime, Drama, Thriller]
# 4   49529  ...           [Action, Adventure, Science Fiction]
#
# [5 rows x 9 columns]

# %%
mov['Poster_Url'][0]
# Out:
# 'https://image.tmdb.org/t/p/original/jRXYjXNq0Cs2TcJjLkki24MLp7u.jpg'

# %%
import pickle

# %%
pickle.dump(movies.to_dict(),open("movies.pkl","wb"))

# %%
pickle.dump(similarity,open("similarity.pkl","wb"))

# %%
movies["title"].duplicated().sum()
# Out:
# np.int64(0)
